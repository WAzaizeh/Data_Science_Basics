# %% [markdown]
# # Assignments
# ## 1.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# Make the random function consistent and replicable.
np.random.seed(1221)

# Make a blank data frame.
df = pd.DataFrame()
df['rand'] = np.random.normal(100, 5, 1000)  # Add a column of random numbers between 0 and 1.
df['rand_sq'] = df['rand'] ** 2
df['rand_shift'] = df['rand'] + 2

# When creating a data frame an index column of counts is created, counting from 0.
# Here we do a few transforms on that index to create some extra columns.
df['counts_sq'] = df.index ** 2 
df['counts_sqrt'] = np.sqrt(df.index)

# Creating histogram for all variable
plt.figure(figsize=(15,12))

c=1
# Histogram plot for all variables 
for column_name, c in zip(column_names, range(1,len(df.columns)+1)):
    plt.subplot(3,2,c)
    c += 1
    plt.hist(df[column_name])
    plt.xlabel('counts', fontsize=20)
    if c % 2 != 1: plt.ylabel('frequency', fontsize=20) # add y-label only to even-number plots (on left side)
    plt.title(column_name, fontsize=20)
    
plt.tight_layout()
plt.show()

# %%
for column_name, c in zip(column_names, range(len(df.columns))):
    print(column_name + '-' + '{}'.format(c))
# Out:
# rand-0
# rand_sq-1
# rand_shift-2
# counts_sq-3
# counts_sqrt-4

# %%
5%2
# Out:
# 1
