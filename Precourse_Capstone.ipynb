# %% [markdown]
# # BIXI Montreal
# There is four CSV file, one for each ear (2014 - 2017)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# set up the figure size
# %matplotlib inline

# preview of each file
def preview_data(data):
    bold = '\033[1m'
    unbold = '\033[0m'
    print(bold + "The dimension of the table is:" + unbold, data.shape)
    print(bold + "\n\nFirst 5 rows preview:\n" + unbold, data.head())
    print(bold + "\n\nThe describtion of numerical columns is:\n" + unbold, data.describe())
    print(bold + "\nAnd the describtion of categorial columns is:\n" + unbold, data.describe(include=['O']))

## BIXI dataset

# BIXI_2015 = pd.read_csv('~/Downloads/biximtl/OD_2015.csv')
# preview_data(BIXI_2015)

# %% [markdown]
# # NYC Turnstile usage data
# There is two csv files (2017 & 2018)

# %%
subway_2017 = pd.read_csv('~/Downloads/nys-turnstile-usage-data/turnstile-usage-data-2017.csv')

preview_data(subway_2017)
# Out:
# The dimension of the table is: (8878203, 11)
#
#
# First 5 rows preview:
#      C/A  Unit       SCP         Station Line Name Division  \
# 0  R629  R065  00-00-01     ROCKAWAY AV         3      IRT
# 1  N317  R267  02-06-00           46 ST        MR      IND
# 2  B025  R150  00-00-00        AVENUE U        BQ      BMT
# 3  A061  R142  00-00-00  DELANCEY/ESSEX      FJMZ      BMT
# 4  R257  R182  01-03-00          116 ST         6      IRT
#
#                       Date      Time Description   Entries  \
# 0  2017-01-06T00:00:00.000  15:00:00     REGULAR   5723234
# 1  2017-01-04T00:00:00.000  16:00:00     REGULAR    281688
# 2  2017-01-01T00:00:00.000  20:00:00     REGULAR   4052069
# 3  2017-01-01T00:00:00.000  16:00:00     REGULAR  10956480
# 4  2017-01-02T00:00:00.000  00:00:00     REGULAR   8620297
#
#    Exits
# 0                                            5956815
# 1                                             388139
# 2                                            2654916
# ...

# %% [markdown]
# # NYC restaurant inspection

# %%
inspection_data = pd.read_csv('~/Downloads/nyc-inspection/DOHMH_New_York_City_Restaurant_Inspection_Results.csv')

preview_data(inspection_data)
# Out:
# The dimension of the table is: (399918, 18)
#
#
# First 5 rows preview:
#        CAMIS                      DBA           BORO BUILDING         STREET  \
# 0  40511702        NOTARO RESTAURANT      MANHATTAN      635  SECOND AVENUE
# 1  40511702        NOTARO RESTAURANT      MANHATTAN      635  SECOND AVENUE
# 2  50046354                 VITE BAR         QUEENS     2507       BROADWAY
# 3  50061389  TACK'S CHINESE TAKE OUT  STATEN ISLAND      11C    HOLDEN BLVD
# 4  41516263               NO QUARTER       BROOKLYN     8015       5 AVENUE
#
#    ZIPCODE       PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0  10016.0  2126863400             Italian      06/15/2015
# 1  10016.0  2126863400             Italian      11/25/2014
# 2  11106.0  3478134702             Italian      10/03/2016
# 3  10314.0  7189839854             Chinese      05/17/2017
# 4  11209.0  7187019180            American      03/30/2017
#
#                                             ACTION VIOLATION CODE  \
# ...

# %% [markdown]
# # Austin, Texas scooter-sharing

# %%
scooter_data = pd.read_csv('~/Downloads/Dockless_Vehicle_Trips.csv')

preview_data(scooter_data)
# Out:
# The dimension of the table is: (4414975, 16)
#
#
# First 5 rows preview:
#                                       ID                             Device ID  \
# 0  6865731e-5e4b-4819-9435-4e62e09a652d  08c8c852-257c-49ad-a14f-727bfc79626d
# 1  08dc0d9c-735e-4006-b9af-60011509e469  255716b5-4a9f-4efc-9967-7a65b3521bac
# 2  9643609b-f548-4ccc-b96c-cc625a34a6c1  a8813574-e5fe-4ce3-ac18-924ddedd1c7e
# 3  da2f4ebd-bdd7-48ee-bc6a-bf94a5798b33  6bf00459-0fce-4b7b-943d-ff169220f90b
# 4  326432d7-b32e-4cd7-94ac-9b1062312421  6847fb45-771a-435c-acaa-05ecf1a2bee8
#
#   Vehicle Type  Trip Duration  Trip Distance              Start Time  \
# 0          NaN            NaN            NaN                     NaN
# 1      bicycle     11491603.0         1658.0  11/30/2018 11:00:00 AM
# 2      scooter           46.0            0.0  10/07/2018 12:45:00 AM
# 3      scooter          181.0            0.0  02/17/2019 12:45:00 AM
# 4      scooter          422.0            0.0  04/14/2019 12:15:00 AM
#
# ...

# %% [markdown]
# ***
# # Chosen dataset: NYC Turnstile usage data
# ## There is two csv files (2017 & 2018)

# %%
subway_2017 = pd.read_csv('~/Downloads/nys-turnstile-usage-data/turnstile-usage-data-2017.csv')
subway_2018 = pd.read_csv('~/Downloads/nys-turnstile-usage-data/turnstile-usage-data-2018.csv')

preview_data(subway_2017)
# Out:
# The dimension of the table is: (8878203, 11)
#
#
# First 5 rows preview:
#      C/A  Unit       SCP         Station Line Name Division  \
# 0  R629  R065  00-00-01     ROCKAWAY AV         3      IRT
# 1  N317  R267  02-06-00           46 ST        MR      IND
# 2  B025  R150  00-00-00        AVENUE U        BQ      BMT
# 3  A061  R142  00-00-00  DELANCEY/ESSEX      FJMZ      BMT
# 4  R257  R182  01-03-00          116 ST         6      IRT
#
#                       Date      Time Description   Entries  \
# 0  2017-01-06T00:00:00.000  15:00:00     REGULAR   5723234
# 1  2017-01-04T00:00:00.000  16:00:00     REGULAR    281688
# 2  2017-01-01T00:00:00.000  20:00:00     REGULAR   4052069
# 3  2017-01-01T00:00:00.000  16:00:00     REGULAR  10956480
# 4  2017-01-02T00:00:00.000  00:00:00     REGULAR   8620297
#
#    Exits
# 0                                            5956815
# 1                                             388139
# 2                                            2654916
# ...

# %%
pd.
